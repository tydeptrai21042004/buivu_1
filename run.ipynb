# %%
# !git clone https://github.com/tydeptrai21042004/buivu_1
# Out:
# Cloning into 'buivu_1'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 31 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 13.97 KiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /kaggle/working/buivu_1
# Out:
# /kaggle/working/buivu_1

# %%
# !python main.py --data /kaggle/input/datasets/asmasadaqat/nasa93/NASA_93_Sheet.csv --output outputs
# Out:
# 2026-05-10 14:59:22.992593: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778425163.265020     110 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778425163.348984     110 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778425164.064993     110 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
